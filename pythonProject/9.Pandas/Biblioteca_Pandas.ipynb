# %%
import pandas as pd
import numpy as np

dados = pd.read_csv('StudentsPerformance.csv')

# %%
# Verificar as cinco primeiras linhas
dados.head()

# %%
# Verifica as cinco ultimas linhas
dados.tail()

# %%
#Verifica a quantidade de linhas e colunas
dados.shape

# %%
# Verifica todas as colunas em forma de objeto
dados.columns

# %%
# Verifica as linhas duplicadas
dados.duplicated().sum()

# %%
# Verifica as informações de armazenamento de dados das colunas
dados.info()

# %%
# Verifica a existencia de valores NaN 
dados.isna().sum()

# %%
# Sumario estatico
dados.describe()

# %%
# Verifica a quantidade de valores únicos em cada coluna
dados.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
# Veirifica quais saão os valores unicos da caluna
dados['race/ethnicity'].unique()

# %%
# Verifica a quatidade dos valores repetidaos da coluna
dados['parental level of education'].value_counts()

# %%
# Ordenar o dataset
columns = ['math score', 'reading score', 'writing score']

dados = dados.sort_values(by = columns, ascending=False).reset_index(drop = True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group E           bachelor's degree      standard
# 1      male        group E           bachelor's degree      standard
# 2    female        group E          associate's degree      standard
# 3      male        group E          associate's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C                some college  free/reduced
# 996  female        group B                some college      standard
# 997  female        group B            some high school  free/reduced
# 998  female        group B                 high school  free/reduced
# 999  female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
dados['Media'] = dados[columns].mean(axis=1)

dados.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group E           bachelor's degree      standard
# 1    male        group E           bachelor's degree      standard
# 2  female        group E          associate's degree      standard
# 3    male        group E          associate's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none         100            100            100
# 1               completed         100            100            100
# 2                    none         100            100            100
# 3               completed         100            100             93
# 4               completed         100             97             99
#
#         Media
# 0  100.000000
# 1  100.000000
# 2  100.000000
# 3   97.666667
# 4   98.666667
