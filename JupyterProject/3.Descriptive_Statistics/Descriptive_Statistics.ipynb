# %% [markdown]
# # **Estatística Descritiva**
# Em sua essência, a Estatística é a ciência que apresenta processos próprios para coletar, <br>
# apresentar e interpretar adequadamente conjuntos de dados, sejam eles numéricos ou não. <br>
# Podese dizer que seu objetivo é o de apresentar informações sobre dados em análise para que se tenha <br>
# maior compreensão dos fatos que os mesmos representam.<p>

# %%
# Importando as bibliotecas 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importando biblioteca para tratamento de avisos
import warnings
warnings.filterwarnings('ignore')

# %%
# Leitura da base de dados (Flores)
baseDados = sns.load_dataset('iris')

# Renomemando as colunas da base de dados
columns = {
    'sepal_length': 'comprimento_sepala', 
    'sepal_width': 'largura_sepala',
    'petal_length': 'comprimento_petala',
    'petal_width': 'largura_petala',
    'species': 'especies'  
}

baseDados.rename(columns= columns, inplace= True)

# Visualizando dos dados
baseDados.head()
# Out:
#    comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#   especies
# 0   setosa
# 1   setosa
# 2   setosa
# 3   setosa
# 4   setosa

# %% [markdown]
# # **Módulo 1 - Medidas de tendência central**
# As medidas de tendência central são assim denominadas por indicarem um ponto em torno do qual se concentram os dados.

# %% [markdown]
# **Média aritmética** <p>
# A média aritmética (X) é a soma de todos os valores observados da variável dividida pelo número total de observações.

# %%
baseDados['comprimento_petala'].mean()

# %% [markdown]
# **Moda** <p>
# A moda (Mo) é o valor que apresenta a maior freqüência da variável entre os valores observados.

# %%
baseDados['comprimento_petala'].mode()

# %% [markdown]
# **Mediana** <p>
# A mediana (Md) é o valor que ocupa a posição central da série de observações de uma variável, em rol, dividindo o conjunto em duas partes iguais, ou seja, a quantidade de valores inferiores à mediana é igual à quantidade de valores superiores a mesma.

# %%
baseDados['comprimento_petala'].median()
# Out:
# np.float64(4.35)

# %% [markdown]
# # **Módulo 2 - Medidas Separatrizes** <p>
# Estas medidas são valores que ocupam posições no conjunto de dados, em rol, dividindo-o
# em partes iguais e podem ser:
# 1. Quartil: Os quartis dividem o conjunto de dados em quatro partes iguais. <br>
# ![Imagem Quartil.PNG](data:image/png;base64,...)

# %%
# Função Describe
baseDados['comprimento_sepala'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: comprimento_sepala, dtype: float64

# %%
min      25%      50%      75%      max
4.3 <--> 5.1 <--> 5.8 <--> 6.4 <--> 7.9

# %%
# Plot do Boxplot
sns.boxplot(x=baseDados['comprimento_sepala'])
# Out:
# <Axes: xlabel='comprimento_sepala'>

# %% [markdown]
# # **Módulo 3 - Medidas de dispersão** <p>
#  As medidas de dispersão auxiliam as medidas de tendência central a descrever o conjunto de dados adequadamente. Indicam se os dados estão, ou não, próximos uns dos outros.

# %% [markdown]
# **Amplitude Total** <p>
# A amplitude total de um conjunto de dados é a diferença entre o maior e o menor valor observado.

# %%
baseDados['comprimento_sepala'].max() - baseDados['comprimento_sepala'].min()
# Out:
# np.float64(3.6000000000000005)

# %% [markdown]
# **Amplitude Interquartílica** <p>
# A amplitude interquartílica é a diferença entre o terceiro e o primeiro quartil. Esta medida é mais estável que a amplitude total por não considerar os valores mais extremos

# %%
baseDados['comprimento_sepala'].describe()[6:7].values - baseDados['comprimento_sepala'].describe()[4:5].values
# Out:
# array([1.3])

# %% [markdown]
# **Amplitude semi-interquartílica** <p>
# A amplitude semi-interquartílica é definida como a média aritmética da
# diferença entre a mediana e os quartis.

# %%
(baseDados['comprimento_sepala'].describe()[6:7].values - baseDados['comprimento_sepala'].describe()[4:5].values) / 2
# Out:
# array([0.65])

# %% [markdown]
# **Variância** <p> Uma medida de dispersão que mostra quão distantes os valores estão da média

# %%
baseDados['comprimento_sepala'].var()
# Out:
# np.float64(0.6856935123042507)

# %% [markdown]
# **Desvio padrão** <p>
# é simplesmente o resultado positivo da raiz quadrada da variância.

# %%
baseDados['comprimento_sepala'].std()
# Out:
# np.float64(0.828066127977863)
