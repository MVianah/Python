# %% [markdown]
# **Visualização de dados com Matplotlib**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Grafico de Linhas**

# %%
y = np.random.randint(low=1, high=1500, size=10)

y
# Out:
# array([1162, 1220, 1097,  945,  258,  401, 1399, 1374,  941,  605],
#       dtype=int32)

# %%
plt.plot(y)
